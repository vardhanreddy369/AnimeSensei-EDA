# %% [markdown]
# <a href="https://colab.research.google.com/github/vardhanreddy369/AnimeSensei-EDA/blob/main/AnimeSensei.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

anime_data = pd.read_csv('anime.csv')

print(anime_data.head())

print(anime_data.describe())


print(anime_data.isnull().sum())


sns.histplot(anime_data['rating'], bins=20, kde=True)
plt.xlabel('Rating')
plt.ylabel('Count')
plt.title('Distribution of Anime Ratings')
plt.show()

sns.countplot(x='type', data=anime_data)
plt.xlabel('Anime Type')
plt.ylabel('Count')
plt.title('Distribution of Anime Types')
plt.show()

sns.barplot(x='type', y='rating', data=anime_data)
plt.xlabel('Anime Type')
plt.ylabel('Average Rating')
plt.title('Average Rating per Anime Type')
plt.show()

sns.scatterplot(x='rating', y='members', data=anime_data)
plt.xlabel('Rating')
plt.ylabel('Number of Members')
plt.title('Rating vs. Number of Members')
plt.show()
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266
#            anime_id        rating       members
# count  12294.000000  12064.000000  1.229400e+04
# mean   14058.221653      6.473902  1.807134e+04
# ...

# %% [markdown]
# # New Section
